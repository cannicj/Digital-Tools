# %% [markdown]
# Interactive playground:
# Internet connection is needed to run the playground application as it fetches data live from FRED and Yahoo Finance APIs
# One run can take up to 20s

# %%
# %matplotlib widget
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
sys.path.append('../../src/visualization')
from playground import playground
playground()
# Out:
# Processing currency data.
# Processing SPX data.
# VBox(children=(HTML(value='<h3>Select the dates for the analysis (training + test set). No dates earlier than …
# VBox(children=(HTML(value='<h3>Choose whether to include S&P500 as a predictive variable</h3>'), Checkbox(valu…
# VBox(children=(HTML(value='<h3>Choose the prediction lag of the models</h3>'), FloatSlider(value=1.0, descript…
# VBox(children=(HTML(value='<h3>Choose the relative training data set size (5-95%) </h3>'), FloatSlider(value=0…
# VBox(children=(HTML(value='<h3>Choose whether to use a random seed for the training of the models</h3>'), Chec…
# VBox(children=(HTML(value='<h3>Select the currencies to be used as predictive variables</h3>'), HBox(children=…
# VBox(children=(HTML(value='<h3>Select which models are active and model-specific parameters</h3>'), Dropdown(d…
# Output()
# Button(description='Submit', style=ButtonStyle())
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
