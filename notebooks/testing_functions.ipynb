# %% [markdown]
# # Testfile to check if the functions actually work

# %%
#Import needed packages
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

#To plot pretty figures 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

#Import our data
log_returns_currencies = pd.read_csv("../data/processed/log_returns_currency_data.csv")
log_returns_spx = pd.read_csv("../data/processed/log_returns_spx_data.csv")
dataframe = pd.merge(log_returns_currencies, log_returns_spx.iloc[1:], on='DATE', how='inner')
print(dataframe)
# Out:
#             DATE   USDEUR   USDJPY   USDGBP   USDCHF   USDAUD   USDCAD  \
# 0     2013-11-05  0.00341  0.00020 -0.00588 -0.00219  0.00242 -0.00316
# 1     2013-11-06 -0.00444  0.00000 -0.00224  0.00186 -0.00326  0.00278
# 2     2013-11-07  0.01040  0.00041  0.00068 -0.00820  0.00516 -0.00221
# 3     2013-11-08  0.00247 -0.00476  0.00462 -0.00391  0.00934 -0.00430
# 4     2013-11-12 -0.00530 -0.00624  0.00495  0.00478  0.00975 -0.00133
# ...          ...      ...      ...      ...      ...      ...      ...
# 2478  2023-10-23 -0.00509  0.00047 -0.00672 -0.00011 -0.00284  0.00117
# 2479  2023-10-24  0.00480 -0.00040  0.00533 -0.00179 -0.00189 -0.00496
# 2480  2023-10-25  0.00113 -0.00067  0.00247 -0.00179  0.00237 -0.00204
# 2481  2023-10-26  0.00483 -0.00333  0.00223 -0.00490  0.00348 -0.00420
# 2482  2023-10-27 -0.00568  0.00560 -0.00313 -0.00289 -0.00632 -0.00260
#
#        USDNZD   USDSEK   USDSGD   USDNOK    SP500
# 0    -0.00133 -0.00402 -0.00064 -0.00557 -0.00281
# ...

# %%
import sys
sys.path.append('../models')
#from your_module import your_function

# Now you can use your_function in the notebook

from decision_tree_classifier import decision_tree_classifier
from randomforest_classifier import randomforest_classifier
from support_vector_machine import support_vector_machine

# %%
results_rfc = randomforest_classifier(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
# Out:
#              in sample  out of sample
# Classifiers
# DTC           0.629232       0.405797
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fa6ff7607590> in <module>
# ----> 1 results_rfc = randomforest_classifier(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
#
# ~\Desktop\Master 3. Semester\Digital Tools\what_factors_predict_sp500\models\randomforest_classifier.py in randomforest_classifier(dataframe, currencies, include_sp500, lag, train_size, trees, max_depth, leafes)
#      99     plt.xlabel('Year')
#     100     plt.ylabel('CumSum Return')
# --> 101     plt.savefig('classifier.svg', dpi=1000)
#     102     plt.show()
#     103
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# ...

# %%
results_dtc = decision_tree_classifier(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
# Out:
#              in sample  out of sample
# Classifiers
# DTC           0.746373       0.334944
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-deec5ff4a2a7> in <module>
# ----> 1 results_dtc = decision_tree_classifier(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
#
# ~\Desktop\Master 3. Semester\Digital Tools\what_factors_predict_sp500\models\decision_tree_classifier.py in decision_tree_classifier(dataframe, currencies, include_sp500, lag, train_size, max_depth)
#      96     plt.xlabel('Year')
#      97     plt.ylabel('CumSum Return')
# ---> 98     plt.savefig('classifier.svg', dpi=1000)
#      99     plt.show()
#     100
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# ...

# %%
results_svc = support_vector_machine(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
# Out:
#              in sample  out of sample
# Classifiers
# SVC           0.619559       0.404187
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-882f49b84b63> in <module>
# ----> 1 results_svc = support_vector_machine(dataframe, currencies=['USDCHF', 'USDJPY', 'USDEUR', 'USDGBP'], train_size=0.75)
#
# ~\Desktop\Master 3. Semester\Digital Tools\what_factors_predict_sp500\models\support_vector_machine.py in support_vector_machine(dataframe, currencies, include_sp500, lag, train_size)
#      94     plt.xlabel('Year')
#      95     plt.ylabel('CumSum Return')
# ---> 96     plt.savefig('classifier.svg', dpi=1000)
#      97     plt.show()
#      98
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
# ...
